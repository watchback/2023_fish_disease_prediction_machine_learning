# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit
import warnings
warnings.filterwarnings(action='ignore')
plt.rcParams['font.family'] = 'AppleGothic' # For Mac
from sklearn.tree import DecisionTreeClassifier as DTC # 의사결정나무 분류 알고리즘
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score , recall_score , confusion_matrix
from sklearn.metrics import accuracy_score # 정확도 함수
import pickle
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_validate
pd.options.display.max_columns = None
pd.options.display.max_rows = None
from pycaret.classification import *
from sklearn.model_selection import LeaveOneOut

# %%
data = pd.read_csv("/Users/csb/Desktop/Project/넙치 머신러닝/데이터/78features.csv")

# %%
data = data[['Temperature', 'Condition factor', 'T P', 'Wgp2', 'Wgi3', 'Whkp2', 'Whki2-1', 'Wlr1', 'Wlr2-1', 'Wsi2','CLASS']]
data
# Out:
#       Temperature  Condition factor   T P  Wgp2  Wgi3  Whkp2  Whki2-1  Wlr1  \
# 0           12.44             1.828   5.7     0     4      0        0     0
# 1           12.44             2.348   5.4     0     0      8        0     4
# 2           12.44             1.634   4.7     0     8      0        8     4
# 3           12.44             1.906   5.7     4     4      0        8     4
# 4           12.44             2.055   5.9     4     4      4        4     0
# 5           12.44             1.176   4.6     8     0      8        8     8
# 6           12.44             1.036   4.9     0     0      4        8     0
# 7           12.44             1.852   6.1     0     8      0        8     0
# 8           12.44             1.882   5.3     0     4      0        4     4
# 9           12.44             2.247   5.9     8     0      0        8     0
# 10          12.44             2.006   5.2     0     4      0        4     0
# ...

# %%
loocv = LeaveOneOut()
s = setup(data, target = 'CLASS', session_id = 1234, train_size=0.80, fix_imbalance = False,fold=10)
# Out:
# <style type="text/css">
# #T_fb419_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fb419">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb419_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fb419_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb419_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb419_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fb419_row0_col1" class="data row0 col1" >1234</td>
#     </tr>
#     <tr>
#       <th id="T_fb419_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fb419_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fb419_row1_col1" class="data row1 col1" >CLASS</td>
#     </tr>
#     <tr>
#       <th id="T_fb419_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         21:18:35
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_4d084 th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best, plot = 'confusion_matrix')
